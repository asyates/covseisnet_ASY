# %%
from covseisnetfunc import *

# %%
run_covseisnet('whakaari', 'HHZ','2017-02-01','2017-02-03',writeoutdir='JUPY002',average=100, window_duration_sec=100, ss=False, dfac=5)
# Out:
# 2020-11-09 15:18:04: Processing day 32, year 2017, from data in folder whakaari
# 2020-11-09 15:18:04: 2 traces pulled into stream. Pre-processing data...
# 2020-11-09 15:19:15: Pre-processing finished, computing spectral width.
# 2020-11-09 15:19:23: Finished computing spectral width, saving result
# 2020-11-09 15:19:23: Processing day 33, year 2017, from data in folder whakaari
# 2020-11-09 15:19:24: 2 traces pulled into stream. Pre-processing data...
# 2020-11-09 15:20:31: Pre-processing finished, computing spectral width.
# 2020-11-09 15:20:39: Finished computing spectral width, saving result
# 2020-11-09 15:20:39: Processing day 34, year 2017, from data in folder whakaari
# 2020-11-09 15:20:39: 2 traces pulled into stream. Pre-processing data...
# 2020-11-09 15:21:52: Pre-processing finished, computing spectral width.
# 2020-11-09 15:21:59: Finished computing spectral width, saving result

# %%
plotSpectralWidth('JUPY002', '2017-02-01', '2017-02-03', log=True, count=True)
